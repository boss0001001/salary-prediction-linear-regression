# %%
import pandas as pd
import numpy as nm

import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv("loans.csv")

# %%
df.head(10)
# Out:
#    loan_id  customer_id  branch_id       loan_type  loan_amount  \
# 0        1        48019        129       Auto Loan    310670.27
# 1        2        47355         38  Education Loan    599321.65
# 2        3        30661         29       Gold Loan    135377.18
# 3        4         1755         66  Education Loan     20798.63
# 4        5        18763         23  Education Loan     84367.97
# 5        6         6643         24       Home Loan    657821.31
# 6        7        42046         74   Personal Loan    178965.89
# 7        8        15025        122   Personal Loan    767730.85
# 8        9        33238         12       Home Loan     89088.95
# 9       10         8242        132   Personal Loan     72321.80
#
#    interest_rate  term_months  start_date     status
# 0           9.54           60  2020-06-16     Active
# 1          16.20           12  2016-06-05     Active
# 2          10.25           24  2012-07-03     Active
# 3           8.37          180  2013-01-27  Defaulted
# 4           8.97           60  2017-02-11     Active
# 5          11.04           24  2014-12-14     Active
# 6          15.74           36  2014-01-21     Active
# 7           6.62          240  2015-03-19     Closed
# 8           9.77           12  2024-03-08     Closed
# 9          11.17           12  2018-05-24     Active

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   loan_id        22000 non-null  int64
#  1   customer_id    22000 non-null  int64
#  2   branch_id      22000 non-null  int64
#  3   loan_type      22000 non-null  str
#  4   loan_amount    22000 non-null  float64
#  5   interest_rate  22000 non-null  float64
#  6   term_months    22000 non-null  int64
#  7   start_date     22000 non-null  str
#  8   status         22000 non-null  str
# dtypes: float64(2), int64(4), str(3)
# memory usage: 1.5 MB
#             loan_id   customer_id     branch_id   loan_amount  interest_rate  \
# count  22000.000000  22000.000000  22000.000000  2.200000e+04   22000.000000
# mean   11000.500000  30052.203045     75.677818  4.188476e+05      11.511760
# std     6350.997297  17392.068362     43.220947  3.957601e+05       2.884198
# min        1.000000      1.000000      1.000000  2.000165e+04       6.500000
# 25%     5500.750000  14923.000000     38.000000  1.352407e+05       9.030000
# 50%    11000.500000  29977.000000     76.000000  2.968829e+05      11.500000
# 75%    16500.250000  45099.750000    113.000000  5.758236e+05      14.020000
# max    22000.000000  59999.000000    150.000000  4.016132e+06      16.500000
#
#         term_months
# count  22000.000000
# mean      95.041091
# std       75.721432
# min       12.000000
# 25%       24.000000
# 50%       84.000000
# 75%      180.000000
# max      240.000000

# %%
df.isnull().sum()
# Out:
# loan_id          0
# customer_id      0
# branch_id        0
# loan_type        0
# loan_amount      0
# interest_rate    0
# term_months      0
# start_date       0
# status           0
# dtype: int64

# %%
plt.figure(figsize=(9, 6))
plt.scatter(
df["YearsExperience"],
df["Salary"],
label="Actual salary"
)
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Years of Experience versus Salary")
plt.grid(True)
plt.legend()
plt.show()

# %%
X = df[["YearsExperience"]]
y = df["Salary"]
model= LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
intercept = model.intercept_
slope = model.coef_[0]
print(f"Intercept: {intercept:.2f}")
print(f"Slope: {slope:.2f}")
# Out:
# Intercept: 28859.53
# Slope: 8731.94

# %%
y_pred = model.predict(X)

# %%
results = pd.DataFrame({
"YearsExperience": df["YearsExperience"],
"ActualSalary": y,
"PredictedSalary": y_pred
})
results["Residual"] = (
results["ActualSalary"] - results["PredictedSalary"]
)
results.head(10)
# Out:
#    YearsExperience  ActualSalary  PredictedSalary     Residual
# 0              1.1         39343     38464.661346   878.338654
# 1              1.3         46205     40211.049556  5993.950444
# 2              1.5         37731     41957.437765 -4226.437765
# 3              2.0         43525     46323.408289 -2798.408289
# 4              2.2         39891     48069.796498 -8178.796498
# 5              2.9         56642     54182.155231  2459.844769
# 6              3.0         60150     55055.349336  5094.650664
# 7              3.2         54445     56801.737545 -2356.737545
# 8              3.2         64445     56801.737545  7643.262455
# 9              3.7         57189     61167.708069 -3978.708069

# %%
mse = mean_squared_error(y, y_pred)
rmse = nm.sqrt(mse)
print(f"Mean Squared Error: {mse:.2f}")
print(f"Root Mean Squared Error: {rmse:.2f}")
# Out:
# Mean Squared Error: 35006768.19
# Root Mean Squared Error: 5916.65

# %%
plot_data = results.sort_values("YearsExperience")
plt.figure(figsize=(10, 6))
plt.scatter(
results["YearsExperience"],
results["ActualSalary"],
label="Actual salary"
)
plt.plot(
plot_data["YearsExperience"],
plot_data["PredictedSalary"],
linewidth=2,
label="Regression line"
)
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Linear Regression: Experience versus Salary")
plt.grid(True)
plt.legend()
plt.show()

# %%
new_employee = pd.DataFrame({
"YearsExperience": [6.0]
})
predicted_salary = model.predict(new_employee)
print(
f"Predicted salary for 6 years of experience: "
f"{predicted_salary[0]:.2f}"
)
# Out:
# Predicted salary for 6 years of experience: 81251.17
